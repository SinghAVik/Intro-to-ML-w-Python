# %% [markdown]
# Machine learning deals with building predictive models, focuses on using data to engineer decision rules. The benifit is being able to automate the process of making these rules.
#
# Predictive analysis generalizes the rules of a dataset and uses them on new instances.
#
# Regression v. Classification
# Regression: the data 'x' is discrete (made of diffrent classes)
# Classification: the data 'x' is continous (neumerical value)
