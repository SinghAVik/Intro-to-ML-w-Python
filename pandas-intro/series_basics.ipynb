# %%
import pandas as pd
import numpy as np

# %%
#Ways to make series

series_intigers = pd.Series([1, 2, 3, 4, 5])
series_dictonary = pd.Series({'a': 1, 'b': 2, 'c': 3})
series_strings = pd.Series(['hi', 'hello', 'shalom'], dtype = 'string')
series_narry = pd.Series(np.array([1, 2, 3, 4, 5]))
series_function = pd.Series(np.sin(np.linspace(-np.pi, np.pi, 100)))


print(series_intigers)
print(series_dictonary)
print(series_strings)
print(series_narry)
print(series_function)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64
# a    1
# b    2
# c    3
# dtype: int64
# 0        hi
# 1     hello
# 2    shalom
# dtype: string
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64
# 0    -1.224647e-16
# 1    -6.342392e-02
# 2    -1.265925e-01
# 3    -1.892512e-01
# 4    -2.511480e-01
#           ...
# 95    2.511480e-01
# 96    1.892512e-01
# 97    1.265925e-01
# 98    6.342392e-02
# 99    1.224647e-16
# Length: 100, dtype: float64

# %%
#use .iloc for positional indexing

print(series_intigers.iloc[0])
print(series_dictonary.iloc[1])
print(series_strings.iloc[1])
print(series_narry.iloc[3])
print(series_function.iloc[73])

#use .loc for label indexing
print(series_dictonary.loc['b'])
# Out:
# 1
# 2
# hello
# 4
# 0.9968547759519423
# 2

# %%
#rewrite vlaues with this function

series_strings.iloc[2] = 'hola'

series_dictonary.loc['b'] = 99

print(series_strings)
print(series_dictonary)

#to keep index and replace values

array = np.array([5, 6, 7])

series_dictonary.iloc[:] = array

print(series_dictonary)
# Out:
# 0       hi
# 1    hello
# 2     hola
# dtype: string
# a     1
# b    99
# c     3
# dtype: int64
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 13
#      10 #to keep index and replace values
#      12 array = np.array([5, 6, 7, 8])
# ---> 13 series_dictonary.iloc[:] = array
#      15 print(series_dictonary)
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/pandas/core/indexing.py:912, in _LocationIndexer.__setitem__(self, key, value)
#     909 self._has_valid_setitem_indexer(key)
#     911 iloc = self if self.name == "iloc" else self.obj.iloc
# --> 912 iloc._setitem_with_indexer(indexer, value, self.name)
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/pandas/core/indexing.py:1945, in _iLocIndexer._setitem_with_indexer(self, indexer, value, name)
#    1943     self._setitem_with_indexer_split_path(indexer, value, name)
#    1944 else:
# -> 1945     self._setitem_single_block(indexer, value, name)
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/pandas/core/indexing.py:2219, in _iLocIndexer._setitem_single_block(self, indexer, value, name)
#    2216 self.obj._check_is_chained_assignment_possible()
#    2218 # actually do the set
# -> 2219 self.obj._mgr = self.obj._mgr.setitem(indexer=indexer, value=value)
#    2220 self.obj._maybe_update_cacher(clear=True, inplace=True)
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/pandas/core/internals/managers.py:434, in BaseBlockManager.setitem(self, indexer, value, warn)
#     430     # No need to split if we either set all columns or on a single block
#     431     # manager
#     432     self = self.copy()
# --> 434 return self.apply("setitem", indexer=indexer, value=value)
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/pandas/core/internals/managers.py:363, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     361         applied = b.apply(f, **kwargs)
#     362     else:
# --> 363         applied = getattr(b, f)(**kwargs)
#     364     result_blocks = extend_blocks(applied, result_blocks)
#     366 out = type(self).from_blocks(result_blocks, self.axes)
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/pandas/core/internals/blocks.py:1469, in Block.setitem(self, indexer, value, using_cow)
#    1466     values = values.T
#    1468 # length checking
# -> 1469 check_setitem_lengths(indexer, value, values)
#    1471 if self.dtype != _dtype_obj:
#    1472     # GH48933: extract_array would convert a pd.Series value to np.ndarray
#    1473     value = extract_array(value, extract_numpy=True)
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/pandas/core/indexers/utils.py:177, in check_setitem_lengths(indexer, value, values)
#     174 if is_list_like(value):
#     175     if len(value) != length_of_indexer(indexer, values) and values.ndim == 1:
#     176         # In case of two dimensional value is used row-wise and broadcasted
# --> 177         raise ValueError(
#     178             "cannot set using a slice indexer with a "
#     179             "different length than the value"
#     180         )
#     181     if not len(value):
#     182         no_op = True
#
# ValueError: cannot set using a slice indexer with a different length than the value
